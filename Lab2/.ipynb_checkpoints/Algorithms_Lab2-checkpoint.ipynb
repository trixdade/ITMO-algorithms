# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import optimize
import math
import timeit

# %%
def f_1(x):
    return np.power(x, 3)

def f_2(x):
    return np.abs(x-0.2)

def f_3(x):
    return np.multiply(x, np.sin(1/x))

# %%
eps = 0.0001

# %%
def exhaustive_search(f, a, b):
    n = (b-a)/eps
    f_min = f(a)
    count = 1
    x_min = a
    for i in range(int(n)):
        f_new = f(a + i*(b-a)/n)
        count += 1
        if f_new < f_min:
            f_min = f_new
            x_min = a + i*(b-a)/n
    
    return x_min, count, int(n)

# %%
def dichotomy(f, a, b):
    beta = eps/2
    count = 0
    iterations = 0
    while np.abs(a-b) > eps:
        iterations +=1
        x_1 = (a + b - beta)/2
        x_2 = (a + b + beta)/2
        count += 2
        
        if f(x_1) <= f(x_2):
            b = x_2
        else:
            a = x_1
    
    return (a+b) / 2, count, int(iterations)

# %%
invphi = (math.sqrt(5) - 1) / 2 
invphi2 = (3 - math.sqrt(5)) / 2 

def golden_section_search(f, a, b):
    count = 0
    (a, b) = (min(a, b), max(a, b))
    h = b - a

    # Required steps to achieve eps
    n = int(math.ceil(math.log(eps / h) / math.log(invphi)))

    c = a + invphi2 * h
    d = a + invphi * h
    yc = f(c)
    yd = f(d)
    count = 2
    for k in range(n-1):
        if yc < yd:
            b = d
            d = c
            yd = yc
            h = invphi * h
            c = a + invphi2 * h
            yc = f(c)
            count += 1
        else:
            a = c
            c = d
            yc = yd
            h = invphi * h
            d = a + invphi * h
            yd = f(d)
            count += 1

    if yc < yd:
        return (a+d)/2, count, n
    else:
        return (c+b)/2, count, n

# %%
# exhaustive_search
exhaustive_search(f_1, 0, 1)
# Out:
# (0, 10001, 10000)

# %%
exhaustive_search(f_2, 0, 1)
# Out:
# (0.2, 10001, 10000)

# %%
exhaustive_search(f_3, 0.01, 1)
# Out:
# (0.2225, 9901, 9900)

# %%
# dichotomy
dichotomy(f_1, 0, 1)
# Out:
# (4.0258026123046875e-05, 30, 15)

# %%
dichotomy(f_2, 0, 1)
# Out:
# (0.2000119483947754, 30, 15)

# %%
dichotomy(f_3, 0.01, 1)
# Out:
# (0.22254341049194337, 30, 15)

# %%
# golden section search
golden_section_search(f_1, 0, 1)
# Out:
# (3.305348067594804e-05, 21, 20)

# %%
golden_section_search(f_2, 0, 1)
# Out:
# (0.2000198320884056, 21, 20)

# %%
golden_section_search(f_3, 0.01, 1)
# Out:
# (0.22253575499749817, 21, 20)

# %%
alpha = np.random.uniform(0, 1)
beta = np.random.uniform(0, 1)
x = np.linspace(0, 1, 101)
y = np.zeros(101)
y_no_noise = np.zeros(101)

# %%
for i in range(len(x)):
    y[i] = alpha*x[i] + beta + np.random.normal(0, 1)
    
for i in range(len(x)):
    y_no_noise[i] = alpha*x[i] + beta

# %%
def f_linear(a, b, x):
    return a*x + b

def f_rational(a, b, x):
    return a/(1 + b*x)

# %%
eps = 0.001

# %%
plt.figure(figsize=(12,9))
plt.plot(y, label='Noisy data')
plt.plot(y_no_noise, label='Generative line')
plt.legend()

# %%
def least_squares(ab):
    a, b = ab
    global x, y 
    lst_sqr = [(f_linear(x[i],a,b) - y[i]) ** 2 for i in range(len(x))]       
    return np.sum(lst_sqr)

# %%
brute = []
for a in np.linspace(0, 1, 101):
    for b in np.linspace(0, 1, 101):
        value = least_squares([a, b])
        brute.append([value, a, b])

# %%
df = pd.DataFrame(brute).rename(columns={0 : "value", 1 : "alpha", 2 : "beta"})

# %%
lin_exh_val, lin_exh_x, lin_exh_b = df.sort_values(by='value').head(1).values[0]

# %%
lin_gauss_x, lin_gauss_b = optimize.minimize(least_squares, [0, 0], method='Powell', options={'xatol' : 1e-3}).x
# Out:
# C:\Users\rbezaev\AppData\Local\Temp/ipykernel_17516/1611653478.py:1: OptimizeWarning: Unknown solver options: xatol
#   lin_gauss_x, lin_gauss_b = optimize.minimize(least_squares, [0, 0], method='Powell', options={'xatol' : 1e-3}).x

# %%
lin_NM_x, lin_NM_b = optimize.minimize(least_squares, [0, 0], method='Nelder-Mead', options={'xatol' : 1e-3}).x

# %%
plt.figure(figsize=(12,9))
plt.scatter(x, y, marker="x", color='green')
plt.plot(x, y_no_noise, color='red', label='Generative line')
plt.plot(x, [f_linear(x[i], lin_exh_x, lin_exh_b) for i in  range(len(x))], label='Exhaustive Search', color='black', linewidth=1)
plt.plot(x, [f_linear(x[i], lin_gauss_x, lin_gauss_b) for i in  range(len(x))], label='Gauss', color='yellow', linewidth=1)
plt.plot(x, [f_linear(x[i], lin_NM_x, lin_NM_b) for i in  range(len(x))], label='Nelder-Mead', color='blue', linewidth=1)
plt.legend()

# %%
def least_squares_rational(ab):
    a, b = ab
    global x, y 
    lst_sqr = [(f_rational(x[i],a,b) - y[i]) ** 2 for i in range(len(x))]       
    return np.sum(lst_sqr)

# %%
brute_rational = []
for a in np.linspace(0, 1, 101):
    for b in np.linspace(0, 1, 101):
        value = least_squares_rational([a, b])
        brute_rational.append([value, a, b])

# %%
df_rat = pd.DataFrame(brute_rational).rename(columns={0 : "value", 1 : "alpha", 2 : "beta"})

# %%
rat_exh_val, rat_exh_x, rat_exh_b = df_rat.sort_values(by='value').head(1).values[0]

# %%
rat_gauss_x, rat_gauss_b = optimize.minimize(least_squares_rational, [1, 1], method='Powell', options={'disp' : True, 'xatol' : 1e-3}).x
# Out:
# Optimization terminated successfully.
#          Current function value: 101.522300
#          Iterations: 2
#          Function evaluations: 67
# C:\Users\rbezaev\AppData\Local\Temp/ipykernel_17516/1832507486.py:1: OptimizeWarning: Unknown solver options: xatol
#   rat_gauss_x, rat_gauss_b = optimize.minimize(least_squares_rational, [1, 1], method='Powell', options={'disp' : True, 'xatol' : 1e-3}).x

# %%
rat_NM_x, rat_NM_b = optimize.minimize(least_squares_rational, [1, 1], method='Nelder-Mead', options={'disp' : True, 'xatol' : 1e-3}).x
# Out:
# Optimization terminated successfully.
#          Current function value: 101.522300
#          Iterations: 44
#          Function evaluations: 83

# %%
plt.figure(figsize=(12,9))
plt.scatter(x, y, marker="x", color='green')
plt.plot(x, y_no_noise, color='red', label='Generative line')
plt.plot(x, [f_rational(x[i], rat_exh_x, rat_exh_b) for i in  range(len(x))], label='Exhaustive Search', color='black', linewidth=1)
plt.plot(x, [f_rational(x[i], rat_gauss_x, rat_gauss_b)  for i in  range(len(x))], label='Gauss', color='yellow', linewidth=1)
plt.plot(x, [f_rational(x[i], rat_NM_x, rat_NM_b) for i in  range(len(x))], label='Nelder-Mead', color='blue', linewidth=1)
plt.legend()

# %%
rat_NM_b
# Out:
# -0.33261836409352086
