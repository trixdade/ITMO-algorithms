# %%
import timeit

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def flat_to_real_ids(ids, size=100):
    row_indices = np.arange(size - 1, 0, step=-1)
    cum_row_indices = np.cumsum(row_indices)
    ids_row = []
    for idx in ids:
        row_idx = (cum_row_indices <= idx).sum() - (cum_row_indices == idx).sum()
        if row_idx == 0:
            col_idx = idx + row_indices[::-1][row_idx] - 1
        else:
            col_idx = (
                idx - cum_row_indices[row_idx - 1] + row_indices[::-1][row_idx] - 1
            )
        ids_row.append([row_idx, col_idx])
    return np.asarray(ids_row)


def create_adj_matrix(size=100, n_edges=200):
    m = np.zeros((size, size))
    n_indices = (size - 1) * size // 2
    all_indices = np.arange(0, n_indices, dtype=np.int)
    sample_ids = np.random.choice(all_indices, size=n_edges, replace=False)
    m_ids = flat_to_real_ids(sample_ids, size=size)
    edge_weights = np.random.randint(-100, 100, size=(n_edges,))
    edge_weights[edge_weights == 0] = 50
    m[m_ids[:, 0], m_ids[:, 1]] = edge_weights
    m[m_ids[:, 1], m_ids[:, 0]] = edge_weights
    return m


def floyd_warshall(graph, V):
    dist = graph.copy()
    dist[(dist == 0) & ~np.diagflat(np.full(V, True))] = np.inf

    for k in range(V):
        for i in range(V):
            for j in range(V):
                dist[i][j] = min(dist[i, j], dist[i, k] + dist[k, j])
    return dist


def matrix_chain_order(p): 
    n = len(p)
    m = np.zeros((n, n))

    for i in range(1, n): 
        m[i][i] = 0
  
    # L is chain length. 
    for L in range(2, n): 
        for i in range(1, n-L + 1): 
            j = i + L-1
            m[i][j] = np.inf
            for k in range(i, j): 
  
                # Compute the cost of operation
                q = m[i][k] + m[k + 1][j] + p[i-1]*p[k]*p[j] 
                if q < m[i][j]: 
                    m[i][j] = q 
  
    return m[1][n-1]

# %%
floyd_time = []
matrix_time = []

for V in tqdm.tqdm(range(55, 9, -5), desc="Floyd-Warshall"):
    for E in [V * 2, V * 3, V * 4]:
        graph = create_adj_matrix(size=V, n_edges=E)
        t = timeit.timeit(
            stmt=f"floyd_warshall(graph, V)", globals=globals(), number=5
        )
        floyd_time.append({"main_n": V, "n_edges": E, "time": t})

for n_matrices in tqdm.tqdm(range(100, 4, -5), desc="Matrix chain"):
    m_chain = np.random.randint(1, 100, size=(n_matrices + 1,))
    t = timeit.timeit(stmt=f"matrix_chain_order(m_chain)", globals=globals(), number=10)
    matrix_time.append({"main_n": n_matrices, "time": t})

df = pd.DataFrame(matrix_time)
df2 = pd.DataFrame(floyd_time)
# Out:
# Floyd-Warshall:   0%|                                                                           | 0/10 [00:00<?, ?it/s]C:\Users\rbezaev\AppData\Local\Temp/ipykernel_2604/2187233510.py:20: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   all_indices = np.arange(0, n_indices, dtype=np.int)
# Floyd-Warshall: 100%|██████████████████████████████████████████████████████████████████| 10/10 [00:05<00:00,  1.76it/s]
# Matrix chain: 100%|████████████████████████████████████████████████████████████████████| 20/20 [00:10<00:00,  1.90it/s]

# %%
plt.figure(figsize=(12,9))
sns.lineplot(x=df.main_n, y=df.time, label='Matrix chain multiplication')
sns.lineplot(x=df.main_n, y=0.0000019 * df.main_n ** 3, label='O(n^3)')
plt.xlabel("Matrix amount")
plt.savefig('matrix_time.png')

# %%
plt.figure(figsize=(12,9))
sns.lineplot(x=df2.main_n, y=df2.time, label='Floyd-Warshall')
sns.lineplot(x=df2.main_n, y=0.0000035 * df2.main_n ** 3, label='O(n^3)')
plt.savefig('floyd_time.png')
